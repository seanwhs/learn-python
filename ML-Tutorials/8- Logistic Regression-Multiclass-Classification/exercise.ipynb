# %% [markdown]
# ## Exercise
#
# https://github.com/vlevko/ML_codebasics/blob/master/6_logistic_regression_multiclass.ipynb

# %% [markdown]
# Use sklearn.datasets iris flower dataset to train your model using logistic regression. You need to figure out accuracy of your model and use that to predict different samples in your test dataset. In iris dataset there are 150 samples containing following features,
#
#     Sepal Length
#     Sepal Width
#     Petal Length
#     Petal Width
#
# Using above 4 features you will clasify a flower in one of the three categories,
#
#     Setosa
#     Versicolour
#     Virginica
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris.target[0]
# Out:
# np.int64(0)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=1)

# %%
from sklearn import linear_model
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2])

# %%
X_test
# Out:
# array([[5.8, 4. , 1.2, 0.2],
#        [5.1, 2.5, 3. , 1.1],
#        [6.6, 3. , 4.4, 1.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.7, 3.2, 1.6, 0.2],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.4, 3.9, 1.7, 0.4],
#        [7.1, 3. , 5.9, 2.1],
#        [6.4, 3.2, 4.5, 1.5],
#        [6. , 2.9, 4.5, 1.5],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.8, 2.6, 4. , 1.2],
#        [5.6, 3. , 4.5, 1.5],
#        [5.4, 3.4, 1.5, 0.4],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 2.6, 4.4, 1.2],
#        [5.4, 3. , 4.5, 1.5],
#        [6.7, 3. , 5. , 1.7],
#        [5. , 3.5, 1.3, 0.3],
#        [7.2, 3.2, 6. , 1.8],
#        [5.7, 2.8, 4.1, 1.3],
#        [5.5, 4.2, 1.4, 0.2],
#        [5.1, 3.8, 1.5, 0.3],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.3, 2.5, 5. , 1.9]])

# %%
len(X_test)
# Out:
# 30

# %%
y_test
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        1, 0, 2, 1, 0, 0, 1, 2])

# %%
y_test_df = pd.DataFrame(y_test)
y_test_df[0].unique()
# Out:
# array([0, 1, 2])

# %%
model.predict([[5.1, 2.5, 3. , 1.1]]) # X_test[2]
# Out:
# array([1])

# %%
model.predict([[6. , 2.9, 4.5, 1.5]]) # X_test[14]
# Out:
# array([1])

# %%
model.predict([X_test[-1]])
# Out:
# array([2])

# %%
X_test[-1]
# Out:
# array([6.3, 2.5, 5. , 1.9])

# %%
model.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
target_index = 10
iris.data[target_index]
# Out:
# array([5.4, 3.7, 1.5, 0.2])

# %%
model.predict([iris.data[target_index]])
# Out:
# array([0])

# %%
iris.target_names[iris.target[target_index]]
# Out:
# np.str_('setosa')

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]])

# %%
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(50.722222222222214, 0.5, 'Truth')
