# %% [markdown]
# ## Predicting if a person would buy life insurnace based on his age using logistic regression
# ![image-3.png](attachment:image-3.png)
# * This binary logistic regression has only two possible outcomes (i.e. if person buys insurance or he/she doesn't).
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes

# %%
plt.scatter(df['age'], df['bought_insurance'], color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(df[['age']],df['bought_insurance'], test_size=0.1, random_state=1)
len(X_train)
# Out:
# 24

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
prediction = model.predict(X_test)
score = model.score(X_test, y_test)
print(f'Prediction:: {prediction}, Score:: {score}')
# First two customers will not buy insurance.. third and last customer buys insurance
# Model is perfectly accurate
# Out:
# Prediction:: [1 1 0], Score:: 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.08700528, 0.91299472],
#        [0.22894818, 0.77105182],
#        [0.92917454, 0.07082546]])

# %%
print(f'X_test:\n {X_test}')
# Out:
# X_test:
#      age
# 17   58
# 14   49
# 18   19
