# %% [markdown]
# ## Exercise
#
#
# Use carprices.csv. This file has car sell prices for 3 different models. First plot data points on a scatter plot chart to see if linear regression model can be applied. If yes, then build a model that can answer following questions,
#
# 1) Predict price of a mercedez benz that is 4 yr old with mileage 45000
#
# 2) Predict price of a BMW X5 that is 7 yr old with mileage 86000
#
# 3) Tell me the score (accuracy) of your model. (Hint: use LinearRegression().score())

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/carprices.csv')
df.head()
# Out:
#   Car Model  Mileage  Sell Price($)  Age(yrs)
# 0    BMW X5    69000          18000         6
# 1    BMW X5    35000          34000         3
# 2    BMW X5    57000          26100         5
# 3    BMW X5    22500          40000         2
# 4    BMW X5    46000          31500         4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car Model      13 non-null     object
#  1   Mileage        13 non-null     int64
#  2   Sell Price($)  13 non-null     int64
#  3   Age(yrs)       13 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 548.0+ bytes

# %%
dummies = pd.get_dummies(df['Car Model'])
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0     False    True                  False
# 1     False    True                  False
# 2     False    True                  False
# 3     False    True                  False
# 4     False    True                  False
# 5      True   False                  False
# 6      True   False                  False
# 7      True   False                  False
# 8      True   False                  False
# 9     False   False                   True
# 10    False   False                   True
# 11    False   False                   True
# 12    False   False                   True

# %%
merged = pd.concat([df, dummies], axis='columns')
merged
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6    False    True
# 1                  BMW X5    35000          34000         3    False    True
# 2                  BMW X5    57000          26100         5    False    True
# 3                  BMW X5    22500          40000         2    False    True
# 4                  BMW X5    46000          31500         4    False    True
# 5                 Audi A5    59000          29400         5     True   False
# 6                 Audi A5    52000          32000         5     True   False
# 7                 Audi A5    72000          19300         6     True   False
# 8                 Audi A5    91000          12000         8     True   False
# 9   Mercedez Benz C class    67000          22000         6    False   False
# 10  Mercedez Benz C class    83000          20000         7    False   False
# ...

# %%
final = merged.drop(['Car Model', 'Audi A5'], axis='columns')
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  BMW X5  Mercedez Benz C class
# 0     69000          18000         6    True                  False
# 1     35000          34000         3    True                  False
# 2     57000          26100         5    True                  False
# 3     22500          40000         2    True                  False
# 4     46000          31500         4    True                  False
# 5     59000          29400         5   False                  False
# 6     52000          32000         5   False                  False
# 7     72000          19300         6   False                  False
# 8     91000          12000         8   False                  False
# 9     67000          22000         6   False                   True
# 10    83000          20000         7   False                   True
# 11    79000          21000         7   False                   True
# 12    59000          33000         5   False                   True

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
X = final.drop(['Sell Price($)'], axis='columns')
X
# Out:
#     Mileage  Age(yrs)  BMW X5  Mercedez Benz C class
# 0     69000         6    True                  False
# 1     35000         3    True                  False
# 2     57000         5    True                  False
# 3     22500         2    True                  False
# 4     46000         4    True                  False
# 5     59000         5   False                  False
# 6     52000         5   False                  False
# 7     72000         6   False                  False
# 8     91000         8   False                  False
# 9     67000         6   False                   True
# 10    83000         7   False                   True
# 11    79000         7   False                   True
# 12    59000         5   False                   True

# %%
y = final['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
# Predict price of a mercedez benz that is 4 yr old with mileage 45000
# Predict price of a BMW X5 that is 7 yr old with mileage 86000
# Tell me the score (accuracy) of your model. (Hint: use LinearRegression().score())

model.fit(X,y)
p1 = model.predict([[4500,4,0,1]])
p2 = model.predict([[8600,7,1,0]])
score = model.score(X,y)
print(f'p1::{p1}, p2::{p2}, score:: {score}')
# Out:
# p1::[51981.26203334], p2::[39728.19323785], score:: 0.9417050937281082
# d:\Users\Sean\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# d:\Users\Sean\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
